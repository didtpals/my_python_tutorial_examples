# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
#sns.set(style='darkgrid')

# %%
tips = sns.load_dataset['']
tips
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12788\31407049.py in <module>
# ----> 1 tips = sns.load_dataset['gold', 'diamond']
#       2 tips
#
# TypeError: 'function' object is not subscriptable

# %%
sns.joinplot(x='total_bill', y='tip', data=tips)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12788\2462228340.py in <module>
# ----> 1 sns.joinplot(x='total_bill', y='tip', data=tips)
#
# AttributeError: module 'seaborn' has no attribute 'joinplot'

# %%
sns.lineplot(x='total_bill', y='tip', data = tips, hue = 'smoker')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
import pandas as pd
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64
